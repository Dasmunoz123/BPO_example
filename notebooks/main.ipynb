# %%
import numpy as np
import pandas as pd

# %%
file = "../2023-10-31 5_50pm.csv"
chunk_size = 100e3
chunks = pd.read_csv(filepath_or_buffer=file, chunksize=chunk_size, low_memory=False)       # type: ignore
first_df = next(chunks)

## Extracting information about first dataframe
print(first_df.info())
print("\n")
print(first_df.columns.to_list())
print("\n")
print(first_df.head(10))
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Columns: 164 entries, SOURCE to IS_CONTACT_RATE
# dtypes: bool(16), float64(61), int64(1), object(86)
# memory usage: 114.4+ MB
# None
#
#
# ...

# %%
print(len(first_df['ID'].unique()))    # Unique ID
print(len(first_df['ORDER_ID'].unique()))    # Unique ORDER_ID
# Out:
# 100000
# 68196

# %%
nat = first_df[['USER_VALUE', 'CUSTOM', 'FINAL_USER_VALUE']]
nat.head(10)
# Out:
#      USER_VALUE                                             CUSTOM  \
# 0  Unidentified  {"authorIdStr":"89758","authorTypeStr":"storek...
# 1            LV  {"authorIdStr":"161313667","authorTypeStr":"en...
# 2            LV  {"articleIdStr":"5d5f2ba0bd60b10013bf16c2","au...
# 3  Unidentified  {"authorIdStr":"86115","authorTypeStr":"storek...
# 4  Unidentified  {"authorIdStr":"100633","authorTypeStr":"store...
# 5  Unidentified  {"authorIdStr":"123891","authorTypeStr":"store...
# 6  Unidentified  {"articleIdStr":"5eca8d0b14d7760019cdd6dc","au...
# 7            HV  {"articleIdStr":"5d5f2c018f1ede0012c51e33","au...
# 8            HV  {"articleIdStr":"5e6a2682598464001a8d0569","au...
# 9  Unidentified  {"authorIdStr":"103310","authorTypeStr":"store...
#
#   FINAL_USER_VALUE
# 0              NaN
# 1               LV
# 2               LV
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7               HV
# 8               HV
# 9              NaN

# %%
target_columns = ['CREATED_AT','AHT_LS', 'SURVEY_RATING', 'FRT_QUEUE', 'SLA']
first_df = first_df[target_columns]
first_df.info()
first_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   CREATED_AT     1000000 non-null  object
#  1   AHT_LS         439063 non-null   float64
#  2   SURVEY_RATING  92685 non-null    float64
#  3   FRT_QUEUE      669997 non-null   float64
#  4   SLA            386273 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 38.1+ MB
#                  CREATED_AT  AHT_LS  SURVEY_RATING   FRT_QUEUE  SLA
# 0  2020-05-08T23:25:02.146Z     NaN            NaN  148754.053  0.0
# 1  2020-03-18T19:13:02.217Z     NaN            NaN   55511.403  0.0
# 2  2020-05-29T20:10:36.764Z     NaN            NaN         NaN  0.0
# 3   2020-03-07T19:58:47.69Z     NaN            NaN  412841.272  0.0
# 4  2020-03-25T19:55:39.036Z     NaN            NaN       0.639  1.0
